# %%
age = int(input("Enter your age"))
print(age)
# Out:
# Enter your age 45
# 45

# %%
marks = float(input("Enter Marks:"))
print(marks)
# Out:
# Enter Marks: 67898
# 67898.0

# %%
#Exerecise--WAP to take user Name and age as input and print like Hello<name>,you are <age> year old and going to be <age+1> next year

name = input("Enter your Name:")
Age = int (input("Enter Your Age :"))
print("Hello" , name , " , You are ",Age , "year old and going to be " , Age+1 , "next year")
# Out:
# Enter your Name: shail
# Enter Your Age : 34
# Hello shail  , You are  34 year old and going to be  35 next year

# %%
#2. WAp to take 4 sub marks from user and print average

sub1 = int(input("enter first subject marks:"))
sub2 = int(input("enter second subject marks:"))
sub3 = int(input("enter third subject marks:"))
sub4 = int(input("Enter forth subject marks:"))
average = (sub1+sub2+sub3+sub4)/4
print("average",average)
# Out:
# enter first subject marks: 56
# enter second subject marks: 78
# enter third subject marks: 90
# Enter forth subject marks: 78
# average 75.5
