# %%
# #  bitwise operator
# '''
# 1. & : Bitwise AND
# 2.  |:

# %%
print(f"Bitwise NOT : {~12} ")
print(f"Bitwise NOT : {~8} ")
# Out:
# Bitwise NOT : -13
# Bitwise NOT : -9

# %%
print(5 & 3)
print(5|3)
print(5^3)
print(5 << 3)
print(5>>3)
# Out:
# 1
# 7
# 6
# 40
# 0

# %%
a=5
print(f"{a <<1}")
print(f"{a <<2}")
print(f"{a <<3}")
# Out:
# 10
# 20
# 40

# %%
a=5
print(f"{a >> 1}")
print(f"{a >> 2}")
print(f"{a >> 3}")
# Out:
# 2
# 1
# 0

# %%
print("enter name")
name = input()
print("Enter age:")
age = int( input())

print(f"Name:{name}")
print(f"Age:{age}")

print(type(name))
print(type(age))
# Out:
# enter name

# %%
name = input("Enter name:")
age = int(input("enter age"))

print(f"Name:{name}")
print(f"Age:{age}")

print(type(name))
print(type(age))
# Out:
# Enter name: shail
# enter age 77777777
# Name:shail
# Age:77777777
# <class 'str'>
# <class 'int'>

# %%
'''
1. int()
2. bool()
3. list()
4. tuple()
5. set()
6. ord()
7. chr()
'''

# %%
name = input("enter name:")
age,roll = int(input("enter number:"))
print
